# %% [markdown]
# # RETAIL SALES ANALYTIC

# %%
# Import library of python for ANALYTIC¶

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Users\\parik\\OneDrive\\Desktop\\retailproject\\retailsales.csv')
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
#shape -It give shape (rows ,column)

# %%
df.shape
# Out:
# (1000, 17)

# %%
#column() - it gives column names of dataset

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
# info() - get information about our dataset like total number rows ,*total no. of columns, *datatype ,of each column and *memory requirement

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# Line graph- It is the graph of (quantity VS payment)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Payment', y='Quantity', estimator='sum', ci=None)
plt.title('Quantity VS Payment')
plt.xlabel('Payment ')
plt.ylabel('Quantity')
plt.xticks(rotation=45)
plt.show()

# %%
# isnull()- it tells about the data have null values or not,

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# #no null are present in data

# %%
# duplicate() - when the data is same then it shows * True or the data is not same then its shows *False

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
# drop() - it is used for delete a column or row

# %%
# To remove the object data from dataset
# now drop a column

# %%
df.drop(['Invoice ID'],axis=1,inplace=True)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
#coping the data from df to df2 .....

# %%
df2=df.copy()
df2
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
# data is copied

# %%
df2.drop(['Branch','City','Customer type','Gender'], axis=1, inplace=True)

# %%
df2
# Out:
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# 2        Home and lifestyle       46.33         7  16.2155   340.5255
# 3         Health and beauty       58.22         8  23.2880   489.0480
# 4         Sports and travel       86.31         7  30.2085   634.3785
# ..                      ...         ...       ...      ...        ...
# 995       Health and beauty       40.35         1   2.0175    42.3675
# 996      Home and lifestyle       97.38        10  48.6900  1022.4900
# 997      Food and beverages       31.84         1   1.5920    33.4320
# 998      Home and lifestyle       65.82         1   3.2910    69.1110
# 999     Fashion accessories       88.34         7  30.9190   649.2990
#
#           Date   Time      Payment    cogs  gross margin percentage  \
# ...

# %%
df2.drop(['Product line'], axis=1, inplace=True)

# %%
df2
# Out:
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# 0         74.69         7  26.1415   548.9715   1/5/2019  13:08      Ewallet
# 1         15.28         5   3.8200    80.2200   3/8/2019  10:29         Cash
# 2         46.33         7  16.2155   340.5255   3/3/2019  13:23  Credit card
# 3         58.22         8  23.2880   489.0480  1/27/2019  20:33      Ewallet
# 4         86.31         7  30.2085   634.3785   2/8/2019  10:37      Ewallet
# ..          ...       ...      ...        ...        ...    ...          ...
# 995       40.35         1   2.0175    42.3675  1/29/2019  13:46      Ewallet
# 996       97.38        10  48.6900  1022.4900   3/2/2019  17:16      Ewallet
# 997       31.84         1   1.5920    33.4320   2/9/2019  13:22         Cash
# 998       65.82         1   3.2910    69.1110  2/22/2019  15:33         Cash
# 999       88.34         7  30.9190   649.2990  2/18/2019  13:28         Cash
#
# ...

# %%
df2.drop(['Time'], axis=1, inplace=True)

# %%
df2.drop(['Payment'], axis=1, inplace=True)

# %%
df2.drop(['Date'], axis=1, inplace=True)

# %%
# all categorical is droped ....

# %%
df2
# Out:
#      Unit price  Quantity   Tax 5%      Total    cogs  \
# 0         74.69         7  26.1415   548.9715  522.83
# 1         15.28         5   3.8200    80.2200   76.40
# 2         46.33         7  16.2155   340.5255  324.31
# 3         58.22         8  23.2880   489.0480  465.76
# 4         86.31         7  30.2085   634.3785  604.17
# ..          ...       ...      ...        ...     ...
# 995       40.35         1   2.0175    42.3675   40.35
# 996       97.38        10  48.6900  1022.4900  973.80
# 997       31.84         1   1.5920    33.4320   31.84
# 998       65.82         1   3.2910    69.1110   65.82
# 999       88.34         7  30.9190   649.2990  618.38
#
#      gross margin percentage  gross income  Rating
# 0                   4.761905       26.1415     9.1
# 1                   4.761905        3.8200     9.6
# 2                   4.761905       16.2155     7.4
# 3                   4.761905       23.2880     8.4
# 4                   4.761905       30.2085     5.3
# ...

# %% [markdown]
# # data standardization-

# %%
df2['gross income']
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross income, Length: 1000, dtype: float64

# %%
mean_gross=df2['gross income'].mean()
mean_gross
# Out:
# 15.379368999999999

# %%
mean_gross=df2['gross income'].mean()
num=df2['gross income']-mean_gross
Z = num/df2['gross income'].std()
Z
# Out:
# 0      0.919147
# 1     -0.987236
# 2      0.071410
# 3      0.675442
# 4      1.266492
#          ...
# 995   -1.141179
# 996    2.844917
# 997   -1.177519
# 998   -1.032415
# 999    1.327172
# Name: gross income, Length: 1000, dtype: float64

# %%
df2['gross income']
# Out:
# 0      26.1415
# 1       3.8200
# 2      16.2155
# 3      23.2880
# 4      30.2085
#         ...
# 995     2.0175
# 996    48.6900
# 997     1.5920
# 998     3.2910
# 999    30.9190
# Name: gross income, Length: 1000, dtype: float64

# %%
mean_gross=df2['gross income'].mean()
num=df2['gross income']-mean_gross
Z = num/df2['gross income'].std()
Z
# Out:
# 0      0.919147
# 1     -0.987236
# 2      0.071410
# 3      0.675442
# 4      1.266492
#          ...
# 995   -1.141179
# 996    2.844917
# 997   -1.177519
# 998   -1.032415
# 999    1.327172
# Name: gross income, Length: 1000, dtype: float64

# %%
mean_gross=df2['gross income'].mean()
mean_gross
# Out:
# 15.379368999999999

# %%
# Get overall statics about the dataset

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# # Data Normalization¶

# %%
sns.displot(df['gross income'])

# %%
#max absolute scaling

# %%
df_temp = df.copy()

# %%
df_temp['gross income'] =df_temp['gross income']/ df_temp['gross income'].abs().max()

# %%
sns.displot(df_temp['gross income'])

# %%
df_temp['cogs'] =df_temp['cogs']/ df_temp['cogs'].abs().max()

# %%
sns.displot(df['cogs'])

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(20,18))
sns.heatmap(df.describe(),linewidths=0.1,fmt='0.1f',annot=True,cmap='PiYG')
# Out:
# <Axes: >

# %% [markdown]
# # Density graph

# %%
plt.figure(figsize=(20,25), facecolor='Purple')
plotnumber =1
for column in df2:
    if plotnumber <=15:
        ax = plt.subplot(5,3,plotnumber)
        sns.distplot(df2[column], color='b',hist=False,kde_kws={"shade": True})
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
#After analyzing the above graph we can clearly see the outliers and the skewness in the data
#encoding the categorical data

# %%
df=pd.read_csv('C:\\Users\\parik\\OneDrive\\Desktop\\retailproject\\retailsales.csv')

# %%
df3=df.copy()

# %%
df3
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Time']=le.fit_transform(df['Time'])
df['Date']=le.fit_transform(df['Date'])
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total  Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715    26
# 1  Electronic accessories       15.28         5   3.8200   80.2200    87
# 2      Home and lifestyle       46.33         7  16.2155  340.5255    81
# 3       Health and beauty       58.22         8  23.2880  489.0480    19
# 4       Sports and travel       86.31         7  30.2085  634.3785    57
#
#    Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0   146      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# # Box plot

# %%
# Now we will plot boxplot for the detection of outliers

# %%
plt.figure(figsize=(18,15), facecolor='white')
plotnumber =1
for column in df2:
    if plotnumber <=9:
        ax = plt.subplot(3,3,plotnumber)
        sns.boxplot(df2[column], palette='hsv')
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %%
from scipy.stats import zscore
z = np.abs(zscore(df2))
threshold = 3
df4 = df2[(z<3).all(axis = 1)]

# %%
# Copy the Describe again

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total         Date  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749    44.582000
# std      26.494628     2.923431    11.708825   245.885335    25.894745
# min      10.080000     1.000000     0.508500    10.678500     0.000000
# 25%      32.875000     3.000000     5.924875   124.422375    21.000000
# 50%      55.230000     5.000000    12.088000   253.848000    46.000000
# 75%      77.935000     8.000000    22.445250   471.350250    67.000000
# max      99.960000    10.000000    49.650000  1042.650000    88.000000
#
#               Time        cogs  gross margin percentage  gross income  \
# count  1000.000000  1000.00000             1.000000e+03   1000.000000
# mean    251.176000   307.58738             4.761905e+00     15.379369
# std     147.066923   234.17651             6.131498e-14     11.708825
# ...

# %% [markdown]
# # Bar graph

# %%
categories = ['Total', 'cogs', ' Rating']
values = [322.966749,307.58738,6.97270 ]

plt.barh(categories, values, color=['blue', 'yellow', 'purple'])
plt.xlabel('Values')
plt.ylabel('Categories')
plt.title('Horizontal Bar Graph with Color Customization')
plt.show()

# %% [markdown]
# # Univariate analysis

# %%
# find the distribution of customer rating (numerical value )

# %%
sns.displot(df['Rating'])

# %%
# skewness of data

# %%
df['Rating'].skew()
# Out:
# 0.00900964876573073

# %%
# find the distribution of cost of goods sold

# %%
sns.distplot(df['cogs'])
# Out:
# <Axes: xlabel='cogs', ylabel='Density'>

# %%
# skewness value of cogs

# %%
df['cogs'].skew()
# Out:
# 0.8925698049581418

# %%
# Find the distribution of cost of goods sold

# %%
sns.boxplot(df['cogs'])
# Out:
# <Axes: ylabel='cogs'>

# %% [markdown]
# # Bivariate Analysis

# %%
# Scatter plot to examine relationship between Loan_Approved_Gross and Gross_Amount_Disbursed
plt.figure(figsize=( 6,4))
sns.scatterplot(x='Rating', y='cogs', data=df)
plt.title('Rating vs cogs')
plt.xlabel('Rating')
plt.ylabel('cogs')
plt.show()

# %% [markdown]
# # Correlation of heatmap

# %%
import matplotlib.pyplot as mp
import seaborn as sb
# Import file with data
data = pd.read_csv('C:\\Users\\parik\\OneDrive\\Desktop\\retailproject\\retailsales.csv')

# Print data that will be plotted
# Columns shown here are selected by corr() since
# they are ideal for the plot
print(data.corr(numeric_only=True))

# Plotting correlation heatmap
dataplot = sb.heatmap(data.corr(numeric_only=True), cmap="YlGnBu", annot=True)

# Displaying heatmap
mp.show()
# Out:
#                          Unit price  Quantity    Tax 5%     Total      cogs  \
# Unit price                 1.000000  0.010778  0.633962  0.633962  0.633962
# Quantity                   0.010778  1.000000  0.705510  0.705510  0.705510
# Tax 5%                     0.633962  0.705510  1.000000  1.000000  1.000000
# Total                      0.633962  0.705510  1.000000  1.000000  1.000000
# cogs                       0.633962  0.705510  1.000000  1.000000  1.000000
# gross margin percentage         NaN       NaN       NaN       NaN       NaN
# gross income               0.633962  0.705510  1.000000  1.000000  1.000000
# Rating                    -0.008778 -0.015815 -0.036442 -0.036442 -0.036442
#
#                          gross margin percentage  gross income    Rating
# Unit price                                   NaN      0.633962 -0.008778
# Quantity                                     NaN      0.705510 -0.015815
# ...
